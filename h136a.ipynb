# %%
import matplotlib_inline
# make plots prettier
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import scanpy as sc

# %%
# Read each sample individually
cE14F1 = sc.read_10x_h5('cE14F1.h5')
cE14F2 = sc.read_10x_h5('cE14F2.h5')
cE14F3 = sc.read_10x_h5('cE14F3.h5')
cE14M1 = sc.read_10x_h5('cE14M1.h5')
cE14M2 = sc.read_10x_h5('cE14M2.h5')
cE14M3 = sc.read_10x_h5('cE14M3.h5')
cGFPF1 = sc.read_10x_h5('cGFPF1.h5')
cGFPF2 = sc.read_10x_h5('cGFPF2.h5')
cGFPF3 = sc.read_10x_h5('cGFPF3.h5')
cGFPM1 = sc.read_10x_h5('cGFPM1.h5')
cGFPM2 = sc.read_10x_h5('cGFPM2.h5')
cGFPM3 = sc.read_10x_h5('cGFPM3.h5')
eERMF1 = sc.read_10x_h5('eERMF1.h5')
eERMF2 = sc.read_10x_h5('eERMF2.h5')
eERMF3 = sc.read_10x_h5('eERMF3.h5')
eERMM1 = sc.read_10x_h5('eERMM1.h5')
eERMM2 = sc.read_10x_h5('eERMM2.h5')
eERMM3 = sc.read_10x_h5('eERMM3.h5')
eSTRF1 = sc.read_10x_h5('eSTRF1.h5')
eSTRF2 = sc.read_10x_h5('eSTRF2.h5')
eSTRF3 = sc.read_10x_h5('eSTRF3.h5')
eSTRM1 = sc.read_10x_h5('eSTRM1.h5')
eSTRM2 = sc.read_10x_h5('eSTRM2.h5')
eSTRM3 = sc.read_10x_h5('eSTRM3.h5')
lERMF1 = sc.read_10x_h5('lERMF1.h5')
lERMF2 = sc.read_10x_h5('lERMF2.h5')
lERMF3 = sc.read_10x_h5('lERMF3.h5')
lERMM1 = sc.read_10x_h5('lERMM1.h5')
lERMM2 = sc.read_10x_h5('lERMM2.h5')
lERMM3 = sc.read_10x_h5('lERMM3.h5')
lSTRF1 = sc.read_10x_h5('lSTRF1.h5')
lSTRF2 = sc.read_10x_h5('lSTRF2.h5')
lSTRF3 = sc.read_10x_h5('lSTRF3.h5')
lSTRM1 = sc.read_10x_h5('lSTRM1.h5')
lSTRM2 = sc.read_10x_h5('lSTRM2.h5')
lSTRM3 = sc.read_10x_h5('lSTRM3.h5')
# Out:
# /home/zia/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/zia/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/zia/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/zia/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# ...

# %%
#to make Variable names unique
cE14F1.var_names_make_unique()
cE14F2.var_names_make_unique()
cE14F3.var_names_make_unique()
cE14M1.var_names_make_unique()
cE14M2.var_names_make_unique()
cE14M3.var_names_make_unique()
cGFPF1.var_names_make_unique()
cGFPF2.var_names_make_unique()
cGFPF3.var_names_make_unique()
cGFPM1.var_names_make_unique()
cGFPM2.var_names_make_unique()
cGFPM3.var_names_make_unique()
eERMF1.var_names_make_unique()
eERMF2.var_names_make_unique()
eERMF3.var_names_make_unique()
eERMM1.var_names_make_unique()
eERMM2.var_names_make_unique()
eERMM3.var_names_make_unique()
eSTRF1.var_names_make_unique()
eSTRF2.var_names_make_unique()
eSTRF3.var_names_make_unique()
eSTRM1.var_names_make_unique()
eSTRM2.var_names_make_unique()
eSTRM3.var_names_make_unique()
lERMF1.var_names_make_unique()
lERMF2.var_names_make_unique()
lERMF3.var_names_make_unique()
lERMM1.var_names_make_unique()
lERMM2.var_names_make_unique()
lERMM3.var_names_make_unique()
lSTRF1.var_names_make_unique()
lSTRF2.var_names_make_unique()
lSTRF3.var_names_make_unique()
lSTRM1.var_names_make_unique()
lSTRM2.var_names_make_unique()
lSTRM3.var_names_make_unique()

# %%
cE14F1, cE14F2, cE14F3, cE14M1, cE14M2, cE14M3, cGFPF1, cGFPF2, cGFPF3, cGFPM1, cGFPM2, cGFPM3, eERMF1, eERMF2, eERMF3, eERMM1, eERMM2, eERMM3, eSTRF1, eSTRF2, eSTRF3, eSTRM1, eSTRM2, eSTRM3, lERMF1, lERMF2, lERMF3, lERMM1, lERMM2, lERMM3, lSTRF1, lSTRF2, lSTRF3, lSTRM1, lSTRM2, lSTRM3
# Out:
# (AnnData object with n_obs × n_vars = 7424 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 7070 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 7226 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 6707 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 6930 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 8179 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 7511 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 5765 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 10027 × 25627
#      var: 'gene_ids', 'feature_types', 'genome',
#  AnnData object with n_obs × n_vars = 8763 × 25627
# ...

# %%
# Filtering cells and genes for cE14F1
sc.pp.filter_cells(cE14F1, min_genes=200)
sc.pp.filter_genes(cE14F1, min_cells=3)

# Filtering cells and genes for cE14F2
sc.pp.filter_cells(cE14F2, min_genes=200)
sc.pp.filter_genes(cE14F2, min_cells=3)

# Filtering cells and genes for cE14F3
sc.pp.filter_cells(cE14F3, min_genes=200)
sc.pp.filter_genes(cE14F3, min_cells=3)

# Filtering cells and genes for cE14M1
sc.pp.filter_cells(cE14M1, min_genes=200)
sc.pp.filter_genes(cE14M1, min_cells=3)

# Filtering cells and genes for cE14M2
sc.pp.filter_cells(cE14M2, min_genes=200)
sc.pp.filter_genes(cE14M2, min_cells=3)

# Filtering cells and genes for cE14M3
sc.pp.filter_cells(cE14M3, min_genes=200)
sc.pp.filter_genes(cE14M3, min_cells=3)

# Filtering cells and genes for cGFPF1
sc.pp.filter_cells(cGFPF1, min_genes=200)
sc.pp.filter_genes(cGFPF1, min_cells=3)

# Filtering cells and genes for cGFPF2
sc.pp.filter_cells(cGFPF2, min_genes=200)
sc.pp.filter_genes(cGFPF2, min_cells=3)

# Filtering cells and genes for cGFPF3
sc.pp.filter_cells(cGFPF3, min_genes=200)
sc.pp.filter_genes(cGFPF3, min_cells=3)

# Filtering cells and genes for cGFPM1
sc.pp.filter_cells(cGFPM1, min_genes=200)
sc.pp.filter_genes(cGFPM1, min_cells=3)

# Filtering cells and genes for cGFPM2
sc.pp.filter_cells(cGFPM2, min_genes=200)
sc.pp.filter_genes(cGFPM2, min_cells=3)

# Filtering cells and genes for cGFPM3
sc.pp.filter_cells(cGFPM3, min_genes=200)
sc.pp.filter_genes(cGFPM3, min_cells=3)

# Filtering cells and genes for lSTRM3
sc.pp.filter_cells(lSTRM3, min_genes=200)
sc.pp.filter_genes(lSTRM3, min_cells=3)
